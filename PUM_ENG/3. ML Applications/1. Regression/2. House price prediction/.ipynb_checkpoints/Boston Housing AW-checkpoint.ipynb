# %% [markdown]
# # Prognoza cen mieszkań w Bostonie

# %% [markdown]
# ## Problem

# %% [markdown]
# Jaką cenę będzie miało mieszkanie w zadanej okolicy?

# %% [markdown]
# ## Zbiór nauczający

# %%
import pandas as pd
import numpy as np
zbior_nauczajacy = pd.read_csv("Boston.csv")

zbior_nauczajacy.head()
# Out:
#    Unnamed: 0      crim   zn  indus  chas    nox     rm    age     dis  rad  \
# 0         385  16.81180  0.0  18.10     0  0.700  5.277   98.1  1.4261   24
# 1         450   6.71772  0.0  18.10     0  0.713  6.749   92.6  2.3236   24
# 2         444  12.80230  0.0  18.10     0  0.740  5.854   96.6  1.8956   24
# 3         368   4.89822  0.0  18.10     0  0.631  4.970  100.0  1.3325   24
# 4         140   0.29090  0.0  21.89     0  0.624  6.174   93.6  1.6119    4
#
#    tax  ptratio   black  lstat  medv
# 0  666     20.2  396.90  30.81   7.2
# 1  666     20.2    0.32  17.44  13.4
# 2  666     20.2  240.52  23.79  10.8
# 3  666     20.2  375.52   3.26  50.0
# 4  437     21.2  388.08  24.16  14.0

# %% [markdown]
# Cechy:
#
# CRIM - per capita crime rate by town
# ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# INDUS - proportion of non-retail business acres per town.
# CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# NOX - nitric oxides concentration (parts per 10 million)
# RM - average number of rooms per dwelling
# AGE - proportion of owner-occupied units built prior to 1940
# DIS - weighted distances to five Boston employment centres
# RAD - index of accessibility to radial highways
# TAX - full-value property-tax rate per $10,000
# PTRATIO - pupil-teacher ratio by town
# BLACK - where Bk is the proportion of blacks by town
# LSTAT - lower status of the population
#
#
# Cecha, którą chcemy prognozować:
#
# MEDV - Median value of owner-occupied homes in $1000's

# %% [markdown]
# ### Zbiór treningowy i testowy

# %% [markdown]
# Na wstępie, podzielmy losowo nasz zbiór na dwie części:
#
# 1. zbior_treningowy: na tych danych będziemy nauczali modele. Przyjmijmy, że będzie to 80% całego posiadanego zbioru.
# 2. zbior_testowy: na tych danych będziemy testowali nasze modele. Będzie to 20% całego naszego zbioru danych

# %%
from sklearn.model_selection import train_test_split

zbior_treningowy, zbior_testowy = train_test_split(zbior_nauczajacy, test_size=0.2)

#sprawdźmy wymiary
zbior_treningowy.shape, zbior_testowy.shape
# Out:
# ((384, 15), (96, 15))

# %% [markdown]
# ## Model 1

# %% [markdown]
# Zaczniemy od wyboru cech, na których będziemy nauczali nasz model. Przyjmijmy, że będą to wszystkie cechy:
# Od: CRIM - per capita crime rate by town
# Do: LSTAT - lower status of the population
#
# Zwyczajowo, odpowiednie zbiory danych nazywa się:
# X_train: zbiór TRENINGOWY z cechami objaśniającymi
# y_train: zbiór TRENINGOWY z cechą, której chcemy nauczyć się odgadywać.

# %%
cechy_objasniajace = [
    'crim',
    'zn',
    'indus',
    'chas',
    'nox',
    'rm',
    'age',
    'dis',
    'rad',
    'tax',
    'ptratio',
    'black',
    'lstat'
    ]

# %%
X_train = zbior_treningowy.loc[:, cechy_objasniajace] # TRENINGOWY zbiór danych z cechami objaśniającymi
y_train = zbior_treningowy['medv'] # TRENINGOWY zbiór danych z cechą, której chcemy nauczyć się odgadywać.

# %% [markdown]
# A teraz zrobimy to samo, ale dla zbioru, na którym będziemy sprawdzać poprawność naszego modelu.
#
# Zwyczajowo, odpowiednie zbiory danych nazywa się:
# X_test: zbiór TESTOWY z cechami objaśniającymi
# y_test: zbiór TESTOWY z cechą, której chcemy nauczyć się odgadywać.

# %%
X_test = zbior_testowy.loc[:, 'crim':'lstat'] # TESTOWY zbiór danych z cechami objaśniającymi
y_test= zbior_testowy['medv'] # TESTOWY zbiór danych z cechą, której chcemy nauczyć się odgadywać.

# %% [markdown]
# Sprawdźmy jeszcze liczbę rekordów w poszczególnych plikach...

# %%
print("Będziemy mieli %d rekordów treningowych oraz %d rekordów testowych." % (len(X_train), len(X_test)))
# Out:
# Będziemy mieli 384 rekordów treningowych oraz 96 rekordów testowych.

# %% [markdown]
# ### Model

# %% [markdown]
# Zacznijmy od zainicjowania modelu. Będzie to nasz prototyp, jeszcze nie nauczony...

# %%
from sklearn.linear_model import LinearRegression
model_początkowy_1 = LinearRegression()

# %% [markdown]
# ### Trening

# %% [markdown]
# Wytrenujmy nasz model początkowy na danych treningowych ("dopasujmy" (fit) do tych danych)

# %%
model_nauczony_1 = model_początkowy_1.fit(X_train,y_train)

# %% [markdown]
# ### Ewaluacja

# %% [markdown]
# Teraz sprawdzimy, na ile dobrze prognozuje nasz model.

# %% [markdown]
# W pierwszej kolejności poprosimy nasz model o predykcję dla zbioru testowego.
# Wygląda on następująco: jak widać, nie zawiera kolumny ze zmienną prognozowaną.

# %%
X_test.head()
# Out:
#          crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 46    4.22239   0.0  18.10     1  0.770  5.803  89.0  1.9047   24  666
# 395  13.35980   0.0  18.10     0  0.693  5.887  94.7  1.7821   24  666
# 207   0.03548  80.0   3.64     0  0.392  5.876  19.1  9.2203    1  315
# 192   1.05393   0.0   8.14     0  0.538  5.935  29.3  4.4986    4  307
# 151  11.81230   0.0  18.10     0  0.718  6.824  76.5  1.7940   24  666
#
#      ptratio   black  lstat
# 46      20.2  353.04  14.64
# 395     20.2  396.90  16.35
# 207     16.4  395.18   9.25
# 192     21.0  386.85   6.58
# 151     20.2   48.45  22.74

# %% [markdown]
# Poprośmy teraz nasz model o jego prognozy

# %%
prognozy = model_nauczony_1.predict(X_test)

# %% [markdown]
# Obejrzyjmy zbiór z prognozami...

# %%
print(prognozy)
print("\n")
print("Zbiór z prognozami ma %d wartości, zaś zbiór testowy ma ich %d." % (len(prognozy), len(X_test)))
# Out:
# [20.9104634  18.75511754 21.75042159 20.72245309 14.19409832 25.17187398
#  17.14689044 23.80172956 25.10256749 17.73425081 18.54827545 16.13943058
#  25.58473035 14.15428045  0.44850278 32.51056362 27.68289721 15.3981312
#  34.89003579 24.38921608 23.11494371 18.71645105 19.61181307 21.32962602
#  19.57902983 24.24897978 17.25687511  1.02290533 21.29047546 24.82427574
#  19.8032629  33.37671902 15.91770504 23.01869389 32.83415789 20.72223864
#  20.99643483 19.15673548 25.28433596 22.84987098 24.28867468 36.29020027
#  24.3965758  15.51550149 25.1304036  13.45351751 11.75145336 27.65449877
#  29.01951271 20.21139989 31.21092622 35.1702898  16.51099519 18.84118711
#  25.25070364 18.34285899 22.65949655 11.914537   26.16348399 32.64902568
#  17.02902847 20.24899829 18.64249323 24.6972532  20.46624622  5.55506687
#  14.83676327 13.08625159 41.0564934  24.36905751 24.01296429 22.58137691
#  40.72258748 29.98687805 19.73589025 40.00879647 24.21489219 27.14632154
#  24.58839594  3.22955809 18.74519117 20.88020053 17.07956703 19.82925625
#  20.07214674 14.00220559 20.42339412 24.9433451  25.83703066 23.84041278
#  23.06315766 27.34484954 20.34012518 19.69099392 14.74815599 15.87181571]
#
#
# Zbiór z prognozami ma 96 wartości, zaś zbiór testowy ma ich 96.

# %% [markdown]
# Porównajmy teraz prognozy modelu z prawdziwymi danymi ze zbioru y_test.
# Zaczniemy od porównania parami...

# %%
for i in range(len(prognozy)):
    print(prognozy[i], y_test.to_numpy()[i])
# Out:
# 20.910463400911958 16.8
# 18.755117535193342 12.7
# 21.75042158506532 20.9
# 20.72245309251301 23.1
# 14.194098320451669 8.4
# 25.171873975122182 24.1
# 17.146890443886456 19.4
# 23.801729560488617 20.1
# 25.102567491270378 23.8
# 17.734250806459972 18.1
# 18.548275451335865 19.5
# 16.139430583766533 23.1
# 25.584730348844047 25.0
# 14.154280449682762 13.4
# 0.4485027789788205 13.8
# 32.51056361723679 31.6
# 27.682897214274565 26.6
# 15.398131204949888 14.9
# 34.890035791944165 46.7
# 24.389216075465775 25.0
# 23.114943713674734 20.4
# 18.716451051463014 18.2
# 19.611813074699114 18.6
# 21.329626021732643 19.0
# 19.579029826543326 16.4
# 24.248979777618807 24.7
# 17.25687510860163 10.2
# 1.0229053348713109 17.9
# 21.29047545529987 21.0
# 24.824275743890098 22.2
# 19.80326289685643 14.6
# 33.37671901884892 31.6
# 15.917705038853125 14.1
# 23.018693890810454 23.2
# 32.834157885785956 36.1
# 20.722238643976933 19.3
# 20.996434830463954 13.8
# 19.156735476872726 16.0
# 25.284335963596284 25.0
# 22.8498709841027 11.9
# 24.288674678665686 20.5
# 36.290200269756824 36.0
# 24.396575803502827 21.4
# 15.515501493200613 10.4
# 25.13040360208523 22.7
# 13.453517505385275 14.0
# 11.751453356218306 10.8
# 27.654498768285702 25.0
# 29.019512711592512 22.5
# 20.21139988909608 19.6
# 31.210926216296528 32.5
# 35.17028979971351 35.2
# 16.51099519339425 11.7
# 18.841187107035722 19.6
# 25.25070364051294 18.5
# 18.342858990129606 7.2
# 22.65949655367149 21.4
# 11.914537002508467 15.6
# 26.163483991393036 23.3
# 32.64902568208552 37.2
# 17.029028469787836 13.8
# 20.248998286770988 18.3
# 18.64249322951804 14.5
# 24.69725319764574 24.6
# 20.466246215476723 16.8
# 5.555066865910732 7.4
# 14.83676326759699 14.8
# 13.086251589794454 13.5
# 41.056493398901864 50.0
# 24.36905750616299 23.1
# 24.01296428637768 21.4
# 22.58137691492746 26.6
# 40.72258748153006 48.8
# 29.98687805161521 34.9
# 19.73589024582014 15.6
# 40.00879646580738 46.0
# 24.214892189478668 23.0
# 27.14632153921672 23.2
# 24.588395939550885 23.9
# 3.229558094087995 8.8
# 18.745191170657847 15.4
# 20.880200533729912 20.9
# 17.079567025243282 17.6
# 19.829256246660027 19.9
# 20.072146735907364 18.4
# 14.002205586530685 14.5
# 20.423394123256124 24.3
# 24.943345097786576 24.2
# 25.837030657940744 26.5
# 23.84041277780377 19.6
# 23.063157660434214 22.9
# 27.344849543360517 36.2
# 20.340125175257825 19.5
# 19.6909939244364 17.1
# 14.74815599386261 15.4
# 15.8718157119166 15.6

# %% [markdown]
# Na koniec, obliczmy łączną miarę dokładności predykcji: RMSE (Root Mean Square Error).

# %%
from sklearn.metrics import mean_squared_error
rmse_1 = np.sqrt(mean_squared_error(y_test, prognozy))
print('RMSE = ', rmse_1)
# Out:
# RMSE =  4.454050142699265

# %% [markdown]
# Na ile jest to dokładne? Obliczmy rozpiętość wartości skrajnych cen.

# %%
print('Wartość minimalna w zbiorze testowym: %d' %(min(y_test)))
print('Wartość maksymalna w zbiorze testowym: %d' %(max(y_test)))
# Out:
# Wartość minimalna w zbiorze testowym: 7
# Wartość maksymalna w zbiorze testowym: 50

# %%
X_train.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat'],
#       dtype='object')

# %% [markdown]
# ## Model 2

# %% [markdown]
# Wybierz cechy, na których będziesz nauczał(a) model.

# %%
cechy_objasniajace = [
    #'crim',
    'zn',
    #'indus',
    #'chas',
    #'nox',
    #'rm',
    #'age',
    #'dis',
    #'rad',
    #'tax',
    #'ptratio',
    #'black',
    #'lstat'
    ]

# %%
X_train = zbior_treningowy.loc[:, cechy_objasniajace] # TRENINGOWY zbiór danych z cechami objaśniającymi
y_train = zbior_treningowy['medv'] # TRENINGOWY zbiór danych z cechą, której chcemy nauczyć się odgadywać.

# %% [markdown]
# Wybierz odpowiednie cechy w zbiorze testowym

# %%
X_test = zbior_testowy.loc[:, cechy_objasniajace] # TESTOWY zbiór danych z cechami objaśniającymi
y_test= zbior_testowy['medv'] # TESTOWY zbiór danych z cechą, której chcemy nauczyć się odgadywać.

# %% [markdown]
# Sprawdźmy jeszcze liczbę rekordów w poszczególnych plikach...

# %% [markdown]
# ### Model

# %% [markdown]
# Zacznijmy od zainicjowania modelu. Będzie to nasz prototyp, jeszcze nie nauczony...

# %%
from sklearn.linear_model import LinearRegression
model_początkowy_2 = LinearRegression()

# %% [markdown]
# ### Trening

# %% [markdown]
# Wytrenujmy nasz model początkowy na danych treningowych ("dopasujmy" (fit) do tych danych)

# %%
model_nauczony_2 = model_początkowy_2.fit(X_train,y_train)

# %% [markdown]
# ### Ewaluacja

# %% [markdown]
# Teraz sprawdzimy, na ile dobrze prognozuje nasz model.

# %%
prognozy = model_nauczony_2.predict(X_test)

# %% [markdown]
# Porównajmy teraz prognozy modelu z prawdziwymi danymi ze zbioru y_test.
# Obliczmy łączną miarę dokładności predykcji: RMSE (Root Mean Square Error).

# %%
from sklearn.metrics import mean_squared_error
rmse_2 = np.sqrt(mean_squared_error(y_test, prognozy))
print('RMSE_2 = ', rmse_2)
# Out:
# RMSE_2 =  8.250505554982944

# %% [markdown]
# ## Model 3

# %% [markdown]
# Tym razem, poniżej zobaczysz metodę projektowania i tworzenia modelu w najbardziej syntetycznej formie, często spotykanej w realnych zastosowaniach.

# %%
# Zaimportuj niezbędne biblioteki

from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

# Wybierz cechy, na których będziesz nauczał(a) model.
cechy_objasniajace = [
    'crim',
    'zn',
    'indus',
    'chas',
    'nox',
    'rm',
    'age',
    'dis',
    'rad',
    'tax',
    'ptratio',
    'black',
    'lstat'
    ]
# Stwórz zbiory: treningowy i testowy
X_train = zbior_treningowy.loc[:, cechy_objasniajace] # TRENINGOWY zbiór danych z cechami objaśniającymi
y_train = zbior_treningowy['medv'] # TRENINGOWY zbiór danych z cechą, której chcemy nauczyć się odgadywać.

X_test = zbior_testowy.loc[:, cechy_objasniajace] # TESTOWY zbiór danych z cechami objaśniającymi
y_test= zbior_testowy['medv'] # TESTOWY zbiór danych z cechą, której chcemy nauczyć się odgadywać.

# Zainicjuj model
model_początkowy_3 = Ridge()

# Wytrenuj go
model_nauczony_3 = model_początkowy_3.fit(X_train,y_train)

# Sprawdź jego efektywność
prognozy = model_nauczony_3.predict(X_test) #wygeneruj prognozy

# Oblicz miarę efektywności
rmse_3 = np.sqrt(mean_squared_error(y_test, prognozy))
print('RMSE_3 = ', rmse_3)
# Out:
# RMSE_3 =  4.510111097169636

# %% [markdown]
# ## Wnioski

# %%
RMSE = [rmse_1, rmse_2, rmse_3]
for i in range(3):
    print('RMSE_',i+1, ' = ', RMSE[i])
# Out:
# RMSE_ 1  =  4.454050142699265
# RMSE_ 2  =  8.250505554982944
# RMSE_ 3  =  4.510111097169636

# %%
modele = [model_początkowy_1, model_początkowy_2, model_początkowy_3]
for i in range(3):
    print(modele[i])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)
