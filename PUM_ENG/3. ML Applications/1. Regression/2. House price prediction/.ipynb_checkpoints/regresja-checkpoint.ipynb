# %% [markdown]
# # Prognoza cen mieszkań w Bostonie

# %% [markdown]
# ## Problem

# %% [markdown]
# Jaką cenę będzie miało mieszkanie w zadanej okolicy?

# %% [markdown]
# ## Zbiór nauczający

# %%
import pandas as pd
import numpy as np
zbior_nauczajacy = pd.read_csv("Boston.csv")

zbior_nauczajacy.head()
# Out:
#    Unnamed: 0      crim   zn  indus  chas    nox     rm    age     dis  rad  \
# 0         385  16.81180  0.0  18.10     0  0.700  5.277   98.1  1.4261   24
# 1         450   6.71772  0.0  18.10     0  0.713  6.749   92.6  2.3236   24
# 2         444  12.80230  0.0  18.10     0  0.740  5.854   96.6  1.8956   24
# 3         368   4.89822  0.0  18.10     0  0.631  4.970  100.0  1.3325   24
# 4         140   0.29090  0.0  21.89     0  0.624  6.174   93.6  1.6119    4
#
#    tax  ptratio   black  lstat  medv
# 0  666     20.2  396.90  30.81   7.2
# 1  666     20.2    0.32  17.44  13.4
# 2  666     20.2  240.52  23.79  10.8
# 3  666     20.2  375.52   3.26  50.0
# 4  437     21.2  388.08  24.16  14.0

# %% [markdown]
# Cechy:
#
# CRIM - per capita crime rate by town
# ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# INDUS - proportion of non-retail business acres per town.
# CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# NOX - nitric oxides concentration (parts per 10 million)
# RM - average number of rooms per dwelling
# AGE - proportion of owner-occupied units built prior to 1940
# DIS - weighted distances to five Boston employment centres
# RAD - index of accessibility to radial highways
# TAX - full-value property-tax rate per $10,000
# PTRATIO - pupil-teacher ratio by town
# BLACK - where Bk is the proportion of blacks by town
# LSTAT - lower status of the population
#
#
# Cecha, którą chcemy prognozować:
#
# MEDV - Median value of owner-occupied homes in $1000's

# %% [markdown]
# ### Zbiór treningowy i testowy

# %% [markdown]
# Na wstępie, podzielmy losowo nasz zbiór na dwie części:
#
# 1. zbior_treningowy: na tych danych będziemy nauczali modele. Przyjmijmy, że będzie to 80% całego posiadanego zbioru.
# 2. zbior_testowy: na tych danych będziemy testowali nasze modele. Będzie to 20% całego naszego zbioru danych

# %%
from sklearn.model_selection import train_test_split

zbior_treningowy, zbior_testowy = train_test_split(zbior_nauczajacy, test_size=0.2)

#sprawdźmy wymiary
zbior_treningowy.shape, zbior_testowy.shape
# Out:
# ((384, 15), (96, 15))

# %% [markdown]
# ## Model 1

# %% [markdown]
# Zaczniemy od wyboru cech, na których będziemy nauczali nasz model. Przyjmijmy, że będą to wszystkie cechy:
# Od: CRIM - per capita crime rate by town
# Do: LSTAT - lower status of the population
#
# Zwyczajowo, odpowiednie zbiory danych nazywa się:
# X_train: zbiór TRENINGOWY z cechami objaśniającymi
# y_train: zbiór TRENINGOWY z cechą, której chcemy nauczyć się odgadywać.

# %%
cechy_objasniajace = [
    'crim',
    'zn',
    'indus',
    'chas',
    'nox',
    'rm',
    'age',
    'dis',
    'rad',
    'tax',
    'ptratio',
    'black',
    'lstat'
    ]

# %%
X_train = zbior_treningowy.loc[:, cechy_objasniajace] # TRENINGOWY zbiór danych z cechami objaśniającymi
y_train = zbior_treningowy['medv'] # TRENINGOWY zbiór danych z cechą, której chcemy nauczyć się odgadywać.

# %% [markdown]
# A teraz zrobimy to samo, ale dla zbioru, na którym będziemy sprawdzać poprawność naszego modelu.
#
# Zwyczajowo, odpowiednie zbiory danych nazywa się:
# X_test: zbiór TESTOWY z cechami objaśniającymi
# y_test: zbiór TESTOWY z cechą, której chcemy nauczyć się odgadywać.

# %%
X_test = zbior_testowy.loc[:, 'crim':'lstat'] # TESTOWY zbiór danych z cechami objaśniającymi
y_test= zbior_testowy['medv'] # TESTOWY zbiór danych z cechą, której chcemy nauczyć się odgadywać.

# %% [markdown]
# Sprawdźmy jeszcze liczbę rekordów w poszczególnych plikach...

# %%
print("Będziemy mieli %d rekordów treningowych oraz %d rekordów testowych." % (len(X_train), len(X_test)))
# Out:
# Będziemy mieli 384 rekordów treningowych oraz 96 rekordów testowych.

# %% [markdown]
# ### Model

# %% [markdown]
# Zacznijmy od zainicjowania modelu. Będzie to nasz prototyp, jeszcze nie nauczony...

# %%
from sklearn.linear_model import LinearRegression
model_początkowy_1 = LinearRegression()

# %% [markdown]
# ### Trening

# %% [markdown]
# Wytrenujmy nasz model początkowy na danych treningowych ("dopasujmy" (fit) do tych danych)

# %%
model_nauczony_1 = model_początkowy_1.fit(X_train,y_train)

# %% [markdown]
# ### Ewaluacja

# %% [markdown]
# Teraz sprawdzimy, na ile dobrze prognozuje nasz model.

# %% [markdown]
# W pierwszej kolejności poprosimy nasz model o predykcję dla zbioru testowego.
# Wygląda on następująco: jak widać, nie zawiera kolumny ze zmienną prognozowaną.

# %%
X_test.head()
# Out:
#          crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 443   0.17331   0.0   9.69     0  0.585  5.707   54.0  2.3817    6  391
# 442   7.75223   0.0  18.10     0  0.713  6.301   83.7  2.7831   24  666
# 416   0.10612  30.0   4.93     0  0.428  6.095   65.1  6.3361    6  300
# 292   1.65660   0.0  19.58     0  0.871  6.122   97.3  1.6180    5  403
# 116  73.53410   0.0  18.10     0  0.679  5.957  100.0  1.8026   24  666
#
#      ptratio   black  lstat
# 443     19.2  396.90  12.01
# 442     20.2  272.21  16.23
# 416     16.6  394.62  12.40
# 292     14.7  372.80  14.10
# 116     20.2   16.45  20.62

# %% [markdown]
# Poprośmy teraz nasz model o jego prognozy

# %%
prognozy = model_nauczony_1.predict(X_test)

# %% [markdown]
# Obejrzyjmy zbiór z prognozami...

# %%
print(prognozy)
print("\n")
print("Zbiór z prognozami ma %d wartości, zaś zbiór testowy ma ich %d." % (len(prognozy), len(X_test)))
# Out:
# [20.76821552 17.25585871 23.83618886 21.24529758  5.46369419 35.23653823
#  26.49907384 37.4362501  29.08521169 17.82111501 16.1703451  17.70682415
#  25.19823173 19.28373353 19.71849891 19.37727226 26.60144112 14.45426399
#  24.42219052 25.48629081 17.80804913 39.54244519 26.96057053 33.34352437
#  35.15279617 29.41832906 16.13095581 30.44033578 26.03956829 24.91422908
#   1.81622235 26.1280835  22.8414819  17.11366251 40.09162909 18.56325289
#  16.82576601 17.4958796  17.17405887 17.35112181 22.80711843 21.95369274
#  32.77103954 36.15946886 21.51559224 29.0495747  20.36870166 30.72880404
#  22.50422221 21.29331378 13.39132802 34.46678611 32.49370202 31.25003042
#  28.63811959 24.0083411  43.57209694 21.33623284 23.01130954 29.69209717
#  20.84657632 35.10868505 20.71213428 24.12413764 19.37851219 19.47088729
#  17.85708917 14.71728236 27.57279988 14.99772765 27.48643687 21.50268168
#  16.31374248 25.32286192 14.0992812  25.77248016 18.21379004 41.99036054
#  33.60194748 14.10516498 17.20588106 18.1034596  13.73086619 14.05095936
#  10.11997203 14.53954432 23.84119552  7.54780711 21.16426181 23.79739208
#  22.75280286 12.16081972 18.00013899 28.5252979  22.38625048 27.92146295]
#
#
# Zbiór z prognozami ma 96 wartości, zaś zbiór testowy ma ich 96.

# %% [markdown]
# Porównajmy teraz prognozy modelu z prawdziwymi danymi ze zbioru y_test.
# Zaczniemy od porównania parami...

# %%
for i in range(len(prognozy)):
    print(prognozy[i], y_test.to_numpy()[i])
# Out:
# 20.76821551727398 21.8
# 17.25585871386211 14.9
# 23.836188858542947 20.1
# 21.24529757686735 21.5
# 5.46369419278485 8.8
# 35.23653822532983 33.8
# 26.499073835663577 22.6
# 37.436250097659126 42.3
# 29.08521169126918 23.6
# 17.821115011597406 19.9
# 16.17034510421124 13.3
# 17.706824154399147 19.4
# 25.198231729142886 25.0
# 19.283733527650924 20.6
# 19.71849891373086 19.5
# 19.377272262586963 12.5
# 26.601441120160093 22.8
# 14.454263990877642 19.0
# 24.42219051706801 50.0
# 25.486290812333024 29.8
# 17.80804913494115 14.9
# 39.54244519465903 43.5
# 26.960570525567785 20.6
# 33.34352437090252 31.7
# 35.15279616750462 30.1
# 29.41832905678418 24.1
# 16.13095580902302 14.1
# 30.44033577804412 23.5
# 26.039568285360815 20.7
# 24.914229080225873 23.1
# 1.8162223548537213 17.9
# 26.128083498727296 24.8
# 22.84148190117125 22.6
# 17.11366251415842 18.6
# 40.0916290903618 50.0
# 18.563252889301538 16.1
# 16.825766008457535 13.4
# 17.49587959908996 14.1
# 17.17405887046825 17.5
# 17.35112181084309 23.1
# 22.807118427932608 50.0
# 21.953692738971764 20.9
# 32.771039538063356 31.5
# 36.15946886129339 36.5
# 21.515592238547413 19.7
# 29.049574700024486 26.4
# 20.368701662768874 13.3
# 30.728804038542645 23.6
# 22.5042222081174 17.4
# 21.2933137829692 19.3
# 13.391328024272362 9.5
# 34.46678610850908 34.9
# 32.49370201820225 27.0
# 31.250030419867073 31.5
# 28.638119588259176 24.3
# 24.008341096180306 22.2
# 43.57209693558748 50.0
# 21.33623283846568 16.1
# 23.01130953938371 23.1
# 29.692097165749406 30.1
# 20.846576315551033 21.1
# 35.1086850465859 33.1
# 20.71213427647477 22.9
# 24.124137643364485 21.9
# 19.37851218740407 19.9
# 19.470887285912458 18.5
# 17.85708917277633 19.6
# 14.717282356036122 9.6
# 27.572799883678513 22.0
# 14.99772765463922 17.2
# 27.486436874922617 22.0
# 21.502681676644862 20.1
# 16.313742476915003 17.6
# 25.322861921659808 24.0
# 14.099281196160735 11.5
# 25.772480160318096 23.9
# 18.213790035360624 20.1
# 41.990360539769 50.0
# 33.601947484843485 28.5
# 14.105164977604087 13.3
# 17.205881060817333 14.3
# 18.103459602057047 12.6
# 13.730866187461807 10.9
# 14.050959356412648 13.1
# 10.119972032487077 8.3
# 14.539544320132613 11.0
# 23.84119551594075 24.4
# 7.547807114602271 11.9
# 21.16426181406235 19.6
# 23.79739207537906 23.0
# 22.752802855239764 19.8
# 12.160819716054132 16.5
# 18.000138987126377 18.7
# 28.525297899351955 23.3
# 22.386250480048584 20.6
# 27.921462950235345 23.9

# %% [markdown]
# Na koniec, obliczmy łączną miarę dokładności predykcji: RMSE (Root Mean Square Error).

# %%
from sklearn.metrics import mean_squared_error
rmse_1 = np.sqrt(mean_squared_error(y_test, prognozy))
print('RMSE = ', rmse_1)
# Out:
# RMSE =  5.500640723903995

# %% [markdown]
# Na ile jest to dokładne? Obliczmy rozpiętość wartości skrajnych cen.

# %%
print('Wartość minimalna w zbiorze testowym: %d' %(min(y_test)))
print('Wartość maksymalna w zbiorze testowym: %d' %(max(y_test)))
# Out:
# Wartość minimalna w zbiorze testowym: 8
# Wartość maksymalna w zbiorze testowym: 50

# %%
X_train.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat'],
#       dtype='object')

# %% [markdown]
# ## Model 2

# %% [markdown]
# Wybierz cechy, na których będziesz nauczał(a) model.

# %%
cechy_objasniajace = [
    #'crim',
    'zn',
    #'indus',
    #'chas',
    #'nox',
    #'rm',
    #'age',
    #'dis',
    #'rad',
    #'tax',
    #'ptratio',
    #'black',
    #'lstat'
    ]

# %%
X_train = zbior_treningowy.loc[:, cechy_objasniajace] # TRENINGOWY zbiór danych z cechami objaśniającymi
y_train = zbior_treningowy['medv'] # TRENINGOWY zbiór danych z cechą, której chcemy nauczyć się odgadywać.

# %% [markdown]
# Wybierz odpowiednie cechy w zbiorze testowym

# %%
X_test = zbior_testowy.loc[:, cechy_objasniajace] # TESTOWY zbiór danych z cechami objaśniającymi
y_test= zbior_testowy['medv'] # TESTOWY zbiór danych z cechą, której chcemy nauczyć się odgadywać.

# %% [markdown]
# Sprawdźmy jeszcze liczbę rekordów w poszczególnych plikach...

# %% [markdown]
# ### Model

# %% [markdown]
# Zacznijmy od zainicjowania modelu. Będzie to nasz prototyp, jeszcze nie nauczony...

# %%
from sklearn.linear_model import LinearRegression
model_początkowy_2 = LinearRegression()

# %% [markdown]
# ### Trening

# %% [markdown]
# Wytrenujmy nasz model początkowy na danych treningowych ("dopasujmy" (fit) do tych danych)

# %%
model_nauczony_2 = model_początkowy_2.fit(X_train,y_train)

# %% [markdown]
# ### Ewaluacja

# %% [markdown]
# Teraz sprawdzimy, na ile dobrze prognozuje nasz model.

# %%
prognozy = model_nauczony_2.predict(X_test)

# %% [markdown]
# Porównajmy teraz prognozy modelu z prawdziwymi danymi ze zbioru y_test.
# Obliczmy łączną miarę dokładności predykcji: RMSE (Root Mean Square Error).

# %%
from sklearn.metrics import mean_squared_error
rmse_2 = np.sqrt(mean_squared_error(y_test, prognozy))
print('RMSE_2 = ', rmse_2)
# Out:
# RMSE_2 =  8.91511448801631

# %% [markdown]
# ## Model 3

# %% [markdown]
# Tym razem, poniżej zobaczysz metodę projektowania i tworzenia modelu w najbardziej syntetycznej formie, często spotykanej w realnych zastosowaniach.

# %%
# Zaimportuj niezbędne biblioteki

from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

# Wybierz cechy, na których będziesz nauczał(a) model.
cechy_objasniajace = [
    'crim',
    'zn',
    'indus',
    'chas',
    'nox',
    'rm',
    'age',
    'dis',
    'rad',
    'tax',
    'ptratio',
    'black',
    'lstat'
    ]
# Stwórz zbiory: treningowy i testowy
X_train = zbior_treningowy.loc[:, cechy_objasniajace] # TRENINGOWY zbiór danych z cechami objaśniającymi
y_train = zbior_treningowy['medv'] # TRENINGOWY zbiór danych z cechą, której chcemy nauczyć się odgadywać.

X_test = zbior_testowy.loc[:, cechy_objasniajace] # TESTOWY zbiór danych z cechami objaśniającymi
y_test= zbior_testowy['medv'] # TESTOWY zbiór danych z cechą, której chcemy nauczyć się odgadywać.

# Zainicjuj model
model_początkowy_3 = Ridge()

# Wytrenuj go
model_nauczony_3 = model_początkowy_3.fit(X_train,y_train)

# Sprawdź jego efektywność
prognozy = model_nauczony_3.predict(X_test) #wygeneruj prognozy

# Oblicz miarę efektywności
rmse_3 = np.sqrt(mean_squared_error(y_test, prognozy))
print('RMSE_3 = ', rmse_3)
# Out:
# RMSE_3 =  5.546740221273848

# %% [markdown]
# ## Wnioski

# %% [markdown]
# Porównajmy teraz wyniki poszczególnych modeli.

# %%
modele = [model_nauczony_1, model_nauczony_2, model_nauczony_3]
for i in range(3):
    print(modele[i])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
RMSE = [rmse_1, rmse_2, rmse_3]
for i in range(3):
    print('RMSE_',i+1, ' = ', RMSE[i])
# Out:
# RMSE_ 1  =  5.500640723903995
# RMSE_ 2  =  8.91511448801631
# RMSE_ 3  =  5.546740221273848

# %% [markdown]
# ## Eksport modelu do pliku

# %% [markdown]
# Najlepszym modelem jest model model_nauczony_1. Zapiszmy go więc do pliku tak, by móc później z niego korzystać w praktyce.

# %%
import pickle

pickle.dump(model_nauczony_1, open('nasz_regresor.sav', 'wb'))
